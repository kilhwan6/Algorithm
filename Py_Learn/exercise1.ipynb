# %% [markdown]
# ## 실습1

# %% [markdown]
# #### 제공된 exercise1.ipynb 파일에서 문제에서 요구하는 기능을 구현한 다음 메일로 제출한다.
# #### 메일 제목 : 파이썬실습1-성명, 메일주소 : unicodaum@hanmail.net

# %% [markdown]
# ![image.png](attachment:6ff9196d-8b1c-41cf-bd00-bd5dfcd50ca7.png)

# %%
# 1번
num1 = 10
num2 = 5
result = num1 + num2
print(f"덧셈 결과 : {result}")
# Out:
# 덧셈 결과 : 15

# %% [markdown]
# ![image.png](attachment:d86203ea-87b1-478c-aab5-461c6d636d80.png)

# %%
# 2번
name = "정건희"
color_name = "파랑"
print(f"이름은 {name} 이며 {color_name} 을 좋아합니다.")
# Out:
# 이름은 정건희 이며 파랑 을 좋아합니다.

# %% [markdown]
# ![image.png](attachment:6e69a3c5-d44a-455e-9454-88137ab52bfe.png)

# %%
# 3번
food1 = input("음식1:")
food2 = input("음식2:")
food3 = input("음식3:")
print(f"{food1},{food2},{food3}")
print(f"{food1}-{food2}-{food3}")
print(f"{food1}{food2}{food3}")
# Out:
# 음식1: a
# 음식2: b
# 음식3: c
# a,b,c
# a-b-c
# abc

# %% [markdown]
# ![image.png](attachment:34330ebc-7e49-4d05-a419-66b46a02c3e4.png)

# %%
# 4번
pgm_lang_name = "파이썬"
print(f"""{pgm_lang_name}{pgm_lang_name}{pgm_lang_name}{pgm_lang_name}{pgm_lang_name}{pgm_lang_name}{pgm_lang_name}{pgm_lang_name}{pgm_lang_name}{pgm_lang_name}""")
# Out:
# 파이썬파이썬파이썬파이썬파이썬파이썬파이썬파이썬파이썬파이썬

# %% [markdown]
# ![image.png](attachment:79088968-5c41-40ee-94c1-d2f688829316.png)

# %% [markdown]
# ![image.png](attachment:035539a3-e4d3-4cbd-96eb-79902466bd73.png)

# %%
# 5번
num = int(input("숫자 하나를 입력하세요 : "))
sum = 0
if num > 0 :
    for i in range(num+1):
        sum += i
    print(f"합 : {sum}")
else :
    print("양의 값을 입력하세요")
# Out:
# 숫자 하나를 입력하세요 :  -5
# 양의 값을 입력하세요

# %% [markdown]
# ![image.png](attachment:cb88bfae-b2c3-4390-bf86-b838c70b5aca.png)

# %% [markdown]
# ![image.png](attachment:d47f3b15-5153-4dbc-ac13-9f79f03f0a1a.png)

# %% [markdown]
# ![image.png](attachment:50fb5576-3e1c-41cb-a1ac-326e57bb9fdd.png)

# %%
# 6번
name = input("이름을 입력하세요 :")
if len(name) == 0 : 
    print("이름을 입력하지 않았습니다")
else :
    print(f"이름은 {name}이며 {len(name)}글자입니다")
# Out:
# 이름을 입력하세요 : 정건희
# 이름은 정건희이며 3글자입니다
